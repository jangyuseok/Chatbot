# %%
# 소설 제목에 따른 평점 분석 목표

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
df = pd.read_table('/content/drive/MyDrive/python/MLDL/naver_novel_220126_161633.txt')
df.head()
# Out:
#    페이지  ...                                                줄거리
# 0    1  ...  검(劍)은 흉기라지만,그 검을 익혀 사람의 정을 찾는 이.그가 걷는 무도(武道)는 ...
# 1    1  ...            마법과 산업의 시대.한 이름 없는 광산 마을.그곳에 한 천재가 있었다.
# 2    1  ...  수천 번의 환생, 몇 번째인지도 모를 새로운 삶인간 아기로 태어난 이서준!"부부부....
# 3    1  ...  권총수는 저격용 라이플 스코프(Scope)로 이라크 북부에 있는 하드르 마을을 살피...
# 4    1  ...  지구의 표면적 510,065,284.702km2.이 넓은 세계에 내 한 몸 지낼 곳...
#
# [5 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   페이지     250 non-null    int64
#  1   제목      250 non-null    object
#  2   URL     250 non-null    object
#  3   평점      250 non-null    float64
#  4   작가      250 non-null    object
#  5   줄거리     250 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 11.8+ KB

# %%
df.describe()
# Out:
#               페이지          평점
# count  250.000000  250.000000
# mean     5.500000    7.880800
# std      2.878043    1.666307
# min      1.000000    0.000000
# 25%      3.000000    7.500000
# 50%      5.500000    8.100000
# 75%      8.000000    8.800000
# max     10.000000   10.000000

# %%
train_input = df['제목']
train_target = df['평점']

# %%
from sklearn.model_selection import train_test_split
train_input, test_input, train_target, test_target = train_test_split(
    train_input, train_target, test_size=0.2
)

# %%
# 소설 제목 길이의 평균과 중앙값
import numpy as np
lengths = np.array([len(x) for x in train_input])
print(np.mean(lengths), np.median(lengths))
# Out:
# 12.98 12.0

# %%
import matplotlib.pyplot as plt
plt.hist(lengths)
plt.xlabel('length')
plt.ylabel('frequency')
plt.show()
#제목 길이의 평균과 중앙값의 차이가 크지 않아, 정규분포의 모습일 것으로 예상했으나, 길이 7~10사이의 제목이 다른 구간에 비해 다량 분포 한것을 확인
